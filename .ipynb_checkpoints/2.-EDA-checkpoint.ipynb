# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
diamonds = pd.read_csv('diamonds_clean.csv')
diamonds = diamonds.drop('Unnamed: 0', axis=1)

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
#your code here
diamonds.describe()
# Out:
#        Unnamed: 0.1         carat         depth         table        price  \
# count  40445.000000  40445.000000  40445.000000  40445.000000  40445.00000
# mean   29212.464408      0.588532     61.757577     57.347425   2012.48221
# std    17233.029837      0.271139      1.426491      2.254783   1420.95379
# min        1.000000      0.200000     43.000000     43.000000    326.00000
# 25%    10112.000000      0.340000     61.100000     56.000000    810.00000
# 50%    33715.000000      0.520000     61.800000     57.000000   1571.00000
# 75%    43826.000000      0.760000     62.500000     59.000000   3001.00000
# max    53940.000000      2.060000     79.000000     79.000000   5323.00000
#
#                   x             y     clarity_n       color_n             z
# count  40445.000000  40445.000000  40445.000000  40445.000000  40445.000000
# mean       5.255607      5.260107      3.115441      2.438076      3.247009
# std        0.795364      0.788734      1.694003      1.677386      0.494365
# min        3.730000      3.680000      0.000000      0.000000      2.239050
# 25%        4.510000      4.510000      2.000000      1.000000      2.778550
# 50%        5.170000      5.170000      3.000000      2.000000      3.190770
# 75%        5.870000      5.870000      4.000000      4.000000      3.620800
# max        8.110000      8.070000      7.000000      6.000000      5.117000

# %%
diamonds.head()
# Out:
#    Unnamed: 0.1  carat      cut color clarity  depth  table  price     x  \
# 0             1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95
# 1             2   0.21  Premium     E     SI1   59.8   61.0    326  3.89
# 2             3   0.23     Good     E     VS1   56.9   65.0    327  4.05
# 3             4   0.29  Premium     I     VS2   62.4   58.0    334  4.20
# 4             5   0.31     Good     J     SI2   63.3   58.0    335  4.34
#
#       y  clarity_n  color_n         z
# 0  3.98          1        1  2.438475
# 1  3.84          2        1  2.311270
# 2  4.07          4        1  2.310140
# 3  4.23          3        5  2.630160
# 4  4.35          1        6  2.750385

# %%
#your comments here
diamonds.groupby(['cut','color'])['price'].agg('mean')
# Out:
# cut        color
# Fair       D        2942.781250
#            E        2617.091398
#            F        2622.129921
#            G        2579.949580
#            H        2951.292683
#            I        2778.779528
#            J        2691.278481
# Good       D        2281.011029
#            E        2139.853369
#            F        2343.254351
#            G        2339.753145
#            H        2429.099812
#            I        2340.210227
#            J        2509.181818
# Ideal      D        1684.837686
#            E        1690.476066
#            F        1767.818890
#            G        1652.188643
#            H        1892.569798
#            I        1962.674227
#            J        2283.235495
# Premium    D        2001.191047
#            E        1954.467380
#            F        2227.288197
#            G        1928.166411
#            H        2505.611036
#            I        2388.291310
#            J        2659.951501
# Very Good  D        2056.540875
#            E        1933.457661
#            F        2088.395224
#            G        1901.944278
#            H        2338.084639
#            I        2399.234917
#            J        2512.563510
# Name: price, dtype: float64

# %%
diamonds.groupby(['cut'])['price'].agg('mean')
# Out:
# cut
# Fair         2723.118324
# Good         2313.892479
# Ideal        1766.589402
# Premium      2159.270809
# Very Good    2098.061150
# Name: price, dtype: float64

# %%
diamonds.groupby(['color'])['price'].agg('mean')
# Out:
# color
# D    1921.584208
# E    1871.003518
# F    2030.499327
# G    1851.291142
# H    2235.608553
# I    2224.529178
# J    2479.715517
# Name: price, dtype: float64

# %%
diamonds.groupby(['color'])['price'].agg(['min','max'])
# Out:
#        min   max
# color
# D      357  5320
# E      326  5322
# F      342  5321
# G      354  5322
# H      337  5323
# I      334  5322
# J      335  5318

# %%
diamonds.groupby(['clarity'])['price'].agg('mean')
# Out:
# clarity
# I1      2669.840142
# IF      1338.143421
# SI1     2300.752371
# SI2     2926.588607
# VS1     1703.550710
# VS2     1758.177647
# VVS1    1381.769495
# VVS2    1454.187186
# Name: price, dtype: float64

# %%
diamonds.groupby(['clarity'])['price'].agg(['min','max'])
# Out:
#          min   max
# clarity
# I1       345  5313
# IF       369  5027
# SI1      326  5322
# SI2      326  5321
# VS1      327  5322
# VS2      334  5323
# VVS1     336  5288
# VVS2     336  5317

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %%
#your hypotheses here

# There is not doubt that the features like  color, clarity,cut affects the price but the main feature is the size. We can
# see that the variability in each features between min and max is big, and the feature afecting it is the size.

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
#your code here
diamonds.groupby(['color'])[['carat','price']].agg(['min','mean','max'])
# Out:
#       carat                 price
#         min      mean   max   min         mean   max
# color
# D      0.20  0.538501  1.50   357  1921.584208  5320
# E      0.20  0.541435  1.52   326  1871.003518  5322
# F      0.20  0.579079  1.51   342  2030.499327  5321
# G      0.23  0.555601  1.64   354  1851.291142  5322
# H      0.23  0.645325  1.95   337  2235.608553  5323
# I      0.23  0.681833  1.66   334  2224.529178  5322
# J      0.23  0.789305  2.06   335  2479.715517  5318

# %%
(2479.715517 - 1851.291142)/1851.291142
# Out:
# 0.3394519428862476

# %%
diamonds.groupby(['clarity'])[['price']].agg(['min','mean','max'])
# Out:
#         price
#           min         mean   max
# clarity
# I1        345  2669.840142  5313
# IF        369  1338.143421  5027
# SI1       326  2300.752371  5322
# SI2       326  2926.588607  5321
# VS1       327  1703.550710  5322
# VS2       334  1758.177647  5323
# VVS1      336  1381.769495  5288
# VVS2      336  1454.187186  5317

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
#your thoughts here

# We can see the min and max prices are in the same range, and the mean has a 33% variation between the means.
# Same as Clarity, there is another feature that affect every other feature and is the size which determines the price
#between features

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
#your code here
plt.hist(diamonds['color'])
plt.show()
plt.hist(diamonds['clarity'])
plt.show()

# %%
#your comments here
#E ,G anf F are the top colors in our freq

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
#your code here
diamonds.groupby(['carat'])[['price']].agg(['min','mean','max'])
# Out:
#       price
#         min         mean   max
# carat
# 0.20    345   365.166667   367
# 0.21    326   380.222222   394
# 0.22    337   391.400000   470
# 0.23    326   486.143345   688
# 0.24    336   505.185039   963
# ...     ...          ...   ...
# 1.74   4677  4677.000000  4677
# 1.83   5083  5083.000000  5083
# 1.95   5045  5045.000000  5045
# 2.00   5051  5051.000000  5051
# 2.06   5203  5203.000000  5203
#
# [142 rows x 3 columns]

# %%
#your comments
#There is  142 diffrent values of carat

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
#your code here
plt.hist(diamonds['carat'])
plt.show()

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
#your code here
diamonds.groupby(['table'])[['price']].agg(['min','mean','max'])
# Out:
#       price
#         min     mean   max
# table
# 43.0   4997  4997.00  4997
# 44.0    474   474.00   474
# 49.0    630  2290.50  3951
# 50.0   4227  4227.00  4227
# 50.1   3353  3353.00  3353
# ...     ...      ...   ...
# 70.0   1293  2189.25  2859
# 71.0   1633  1633.00  1633
# 73.0   2100  2406.50  2579
# 76.0   2362  2362.00  2362
# 79.0   2301  2301.00  2301
#
# [125 rows x 3 columns]

# %%
#your comments here
plt.hist(diamonds['table'])
plt.show()

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
#your code here
diamonds.groupby(['clarity'])[['price']].agg(['min','mean','max'])
# Out:
#         price
#           min         mean   max
# clarity
# I1        345  2669.840142  5313
# IF        369  1338.143421  5027
# SI1       326  2300.752371  5322
# SI2       326  2926.588607  5321
# VS1       327  1703.550710  5322
# VS2       334  1758.177647  5323
# VVS1      336  1381.769495  5288
# VVS2      336  1454.187186  5317

# %%
#your comments here
plt.hist(diamonds['clarity'])
plt.show()

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
#your thoughts here
#As I mention before features correlated with the size, in this case the carat/weigth is on

# %% [markdown]
# # 4. Taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
#your thoughts here
# Price and carat: we can see higher the value for carat, higher th price
# Price vs Color or clarity there is no much to say, there is a mix so there is no clear thendency

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
# your code here

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %%
#your thoughts here

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
# your code here

diamonds[['price','carat']].corr()
# Out:
#           price     carat
# price  1.000000  0.943999
# carat  0.943999  1.000000

# %%
sns.heatmap(diamonds[['price','carat']].corr(), annot = True, fmt='.2g',cmap= 'coolwarm',)
# Out:
# <AxesSubplot:>

# %%
import scipy.stats
scipy.stats.pearsonr(scipy.stats.pearsonr(diamonds['price'], diamonds['carat']))[0]
# Out:
# 0.9439989272493106

# %%
sns.scatterplot(diamonds['price'], diamonds['carat'],ci =None ,data = diamonds)
# Out:
# C:\dataanalyst\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price', ylabel='carat'>

# %%
sns.regplot(diamonds['price'], diamonds['carat'],scatter_kws={"color": "blue"}, line_kws={"color": "green"})
# Out:
# C:\dataanalyst\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price', ylabel='carat'>

# %% [markdown]
# **What do you think?**

# %%
#your thoughts here
#There is a clear correlation between Price and weight

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#your thoughts here
# Is clear how the size/weigth features have a higher impact in the price

# %% [markdown]
# **Conclusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.

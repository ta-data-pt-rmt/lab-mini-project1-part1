# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
diamonds = pd.read_csv('/Users/amandine/Downloads/lab-mini-project1-part1/diamonds_clean.csv')

diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    clarity_map  color_map
# 0            1          1
# 1            2          1
# 2            4          1
# 3            3          5
# 4            1          6

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
#your code here

diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53933.000000  53933.000000  53933.000000  53933.000000  53933.000000
# mean       0.797884     61.749333     57.457002   3932.155026      5.731901
# std        0.473983      1.432501      2.234052   3988.700283      1.119932
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z   clarity_map     color_map
# count  53933.000000  53933.000000  53933.000000  53933.000000
# mean       5.733736      3.539707      3.051063      2.594200
# std        1.111532      0.692075      1.647118      1.701151
# min        3.170000      1.070000      0.000000      0.000000
# 25%        4.720000      2.910000      2.000000      1.000000
# 50%        5.710000      3.530000      3.000000      3.000000
# 75%        6.540000      4.040000      4.000000      4.000000
# max       10.540000      8.060000      7.000000      6.000000

# %%
color_price_stats = diamonds.groupby('color_map')['price'].describe()

color_price_stats.head()
# Out:
#              count         mean          std    min    25%     50%      75%  \
# color_map
# 0           6774.0  3168.106436  3353.391411  357.0  911.0  1836.5  4212.50
# 1           9797.0  3076.752475  3344.158685  326.0  882.0  1739.0  4003.00
# 2           9540.0  3725.220755  3785.318317  342.0  982.0  2344.5  4870.75
# 3          11290.0  3998.145173  4050.552693  354.0  931.0  2241.5  6048.00
# 4           8302.0  4484.958805  4213.822977  337.0  984.0  3455.5  5978.50
#
#                max
# color_map
# 0          18693.0
# 1          18731.0
# 2          18791.0
# 3          18818.0
# 4          18803.0

# %%
weight_price_stats = diamonds.groupby('carat')['price'].describe()

weight_price_stats.head()
# Out:
#        count        mean        std    min    25%    50%    75%    max
# carat
# 0.20    12.0  365.166667   6.350853  345.0  367.0  367.0  367.0  367.0
# 0.21     9.0  380.222222  20.504742  326.0  386.0  386.0  386.0  394.0
# 0.22     5.0  391.400000  54.532559  337.0  342.0  404.0  404.0  470.0
# 0.23   293.0  486.143345  70.783966  326.0  438.0  498.0  530.0  688.0
# 0.24   254.0  505.185039  88.247951  336.0  437.5  491.0  552.0  963.0

# %%
cut_price_stats = diamonds.groupby('cut')['price'].describe()

cut_price_stats.head()
# Out:
#              count         mean          std    min      25%     50%      75%  \
# cut
# Fair        1609.0  4357.500932  3561.136245  337.0  2050.00  3282.0  5198.00
# Good        4904.0  3929.598083  3682.161085  327.0  1144.75  3054.0  5028.25
# Ideal      21550.0  3457.108445  3807.957720  326.0   878.00  1810.0  4678.00
# Premium    13789.0  4582.477192  4346.983527  326.0  1046.00  3183.0  6296.00
# Very Good  12081.0  3981.664101  3936.010981  336.0   912.00  2647.0  5373.00
#
#                max
# cut
# Fair       18574.0
# Good       18788.0
# Ideal      18806.0
# Premium    18823.0
# Very Good  18818.0

# %%
#your comments here

#

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %%
#your hypotheses here

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
#your code here

color_means = diamonds.groupby('color_map').mean()

color_means
# Out:
# /var/folders/k_/zzt_gt2j0mgf2704mzjrzkcr0000gn/T/ipykernel_92397/2586254861.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   color_means = diamonds.groupby('color_map').mean()
#               carat      depth      table        price         x         y  \
# color_map
# 0          0.657715  61.698066  57.404355  3168.106436  5.417851  5.421928
# 1          0.657867  61.662090  57.491201  3076.752475  5.411580  5.416107
# 2          0.736544  61.694078  57.432998  3725.220755  5.616138  5.620634
# 3          0.771088  61.757449  57.288060  3998.145173  5.678549  5.681198
# 4          0.911627  61.836557  57.518176  4484.958805  5.984776  5.979735
# 5          1.026927  61.846385  57.577278  5091.874954  6.222826  6.222730
# 6          1.162137  61.887215  57.812393  5323.818020  6.519338  6.518105
#
#                   z  clarity_map
# color_map
# 0          3.343320     2.691025
# 1          3.337770     2.969889
# 2          3.465788     3.134382
# 3          3.507966     3.463419
# 4          3.699147     2.933871
# 5          3.846369     2.964035
# 6          4.033251     2.776353

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
#your thoughts here

# The better the color, the more expensive it gets.

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
#your code here

diamonds['color_map'].value_counts().plot(kind='bar', title='Frequency Distribution of Diamond Colors')
# Out:
# <Axes: title={'center': 'Frequency Distribution of Diamond Colors'}>

# %%
#your comments here

# Most of the diamonds do not have a clear color. 
# The clearest color is the rarest (aroung 3500 units)

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
#your code here

carat_means = diamonds.groupby('carat').mean()

carat_means
# Out:
# /var/folders/k_/zzt_gt2j0mgf2704mzjrzkcr0000gn/T/ipykernel_92397/2081305753.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   carat_means = diamonds.groupby('carat').mean()
#            depth      table         price          x          y         z  \
# carat
# 0.20   61.100000  59.333333    365.166667   3.786667   3.753333  2.303333
# 0.21   60.511111  58.444444    380.222222   3.874444   3.837778  2.332222
# 0.22   61.620000  60.400000    391.400000   3.898000   3.848000  2.386000
# 0.23   61.426621  58.034130    486.143345   3.946382   3.973379  2.431468
# 0.24   61.599213  57.488189    505.185039   3.990157   4.019331  2.465591
# ...          ...        ...           ...        ...        ...       ...
# 4.00   63.300000  58.000000  15984.000000  10.010000   9.940000  6.310000
# 4.01   61.750000  61.500000  15223.000000  10.080000  10.020000  6.205000
# 4.13   64.800000  61.000000  17329.000000  10.000000   9.850000  6.430000
# 4.50   65.800000  58.000000  18531.000000  10.230000  10.160000  6.720000
# 5.01   65.500000  59.000000  18018.000000  10.740000  10.540000  6.980000
#
#        clarity_map  color_map
# carat
# 0.20      2.833333   0.833333
# 0.21      2.666667   0.555556
# 0.22      2.600000   1.200000
# 0.23      4.901024   1.481229
# 0.24      4.972441   1.814961
# ...            ...        ...
# 4.00      0.000000   5.000000
# 4.01      0.000000   5.500000
# 4.13      0.000000   4.000000
# 4.50      0.000000   6.000000
# 5.01      0.000000   6.000000
#
# [273 rows x 8 columns]

# %%
#your comments

# the heavier the carat,the more expensive it gets.

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
#your code here

diamonds['carat'].plot(kind='hist', bins=20, title='Histogram of Diamond Carat Weights')
# Out:
# <Axes: title={'center': 'Histogram of Diamond Carat Weights'}, ylabel='Frequency'>

# %%
# The distribution is right-skewed, also known as positively skewed, which means that 
# most of the data points (diamonds) have carat weights on the lower end of the scale, 
# with fewer diamonds having higher carat weights

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
#your code here

table_means = diamonds.groupby('table').mean()

table_means
# Out:
# /var/folders/k_/zzt_gt2j0mgf2704mzjrzkcr0000gn/T/ipykernel_92397/1506131421.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   table_means = diamonds.groupby('table').mean()
#         carat  depth    price      x      y      z  clarity_map  color_map
# table
# 43.0   1.0400  62.90   4997.0  6.450  6.410  4.040         4.00        5.0
# 44.0   0.2900  62.80    474.0  4.200  4.240  2.650         4.00        1.0
# 49.0   0.6500  64.25   2290.5  5.355  5.320  3.425         3.00        3.0
# 50.0   1.5100  61.50   8995.5  7.380  7.295  4.510         2.00        3.0
# 50.1   0.9400  66.00   3353.0  6.130  6.170  4.060         1.00        4.0
# ...       ...    ...      ...    ...    ...    ...          ...        ...
# 71.0   0.6800  58.00   1633.0  5.850  5.700  3.350         2.00        3.0
# 73.0   0.6025  68.90   2406.5  5.520  5.465  3.745         3.25        1.5
# 76.0   0.7900  65.30   2362.0  5.520  5.130  3.350         2.00        3.0
# 79.0   0.8100  68.80   2301.0  5.260  5.200  3.580         1.00        2.0
# 95.0   2.0100  58.60  13387.0  8.320  8.310  4.870         2.00        2.0
#
# [127 rows x 8 columns]

# %%
#your comments here

# No tendencies for the price with table variation

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
#your code here


clarity_means = diamonds.groupby('clarity_map').mean()

clarity_means
# Out:
# /var/folders/k_/zzt_gt2j0mgf2704mzjrzkcr0000gn/T/ipykernel_92397/854779598.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   clarity_means = diamonds.groupby('clarity_map').mean()
#                 carat      depth      table        price         x         y  \
# clarity_map
# 0            1.283846  62.734278  58.303779  3924.168691  6.761093  6.709379
# 1            1.077601  61.771548  57.926613  5062.255576  6.403460  6.394024
# 2            0.850482  61.853042  57.662541  3996.001148  5.888383  5.888256
# 3            0.763850  61.724249  57.418040  3924.166204  5.658633  5.659782
# 4            0.727108  61.667968  57.313966  3839.144308  5.572860  5.579007
# 5            0.596202  61.663778  57.024990  3283.737071  5.218454  5.232118
# 6            0.503131  61.624521  56.883881  2519.512315  4.961721  4.976437
# 7            0.505123  61.510615  56.507207  2864.839106  4.968402  4.989827
#
#                     z  color_map
# clarity_map
# 0            4.224688   3.031039
# 1            3.952434   2.529975
# 2            3.640636   2.551550
# 3            3.492788   2.505630
# 4            3.437928   2.838188
# 5            3.221465   2.430517
# 6            3.062132   2.649152
# 7            3.061659   2.898324

# %%
#your comments here

# the diamonds with the best clarity are the ones that have a cheaper price mean

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
#your thoughts here

# The table_means data doesn't show a clear trend between the table size and price. 

# For clarity, we see an inverse relationship between clarity, the clearer it is, the cheaper.

# Frequency Distribution of Color : most diamonds have a lower color grade.

# Carat Weights :right-skewed distribution, indicating that the majority of diamonds in 
#the dataset are smaller, with fewer large diamonds.

# it seems that carat, color, and clarity are all significant factors affecting the price, 
# with carat weight having the most influence on it. 
# the price of a diamond is most strongly affected by its carat weight, with color and 
# clarity. The size of the diamond seems to be a dominant factor, often overshadowing the effects of color and clarity on price.

# %% [markdown]
# # 4. Taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
#your thoughts here

# Positive correlation between carat and price

# Price Distribution: most diamonds are at the lower end of the price spectrum with 
#fewer diamonds at the high price end

# Depth and Table: most diamonds have depth and table values within a specific preferred range.

# Strongest relationship seems to be those between carat and other variables such as price 
# and dimensions, due to their strong correlation.

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
# your code here

corr = diamonds.corr()

mask = np.triu(np.ones_like(corr, dtype=bool))

f, ax = plt.subplots(figsize=(11, 9))

cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()
# Out:
# /var/folders/k_/zzt_gt2j0mgf2704mzjrzkcr0000gn/T/ipykernel_92397/2760377400.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = diamonds.corr()

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %%
#your thoughts here

# Yes, carat has a strong posiive correlation with price, while clarity as a strong negative correlation with the price

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
# your code here

from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds['carat'], diamonds['price'])

print(f"Slope: {slope}")
print(f"Intercept: {intercept}")
print(f"R-squared: {r_value**2}")
print(f"P-value: {p_value}")
print(f"Standard Error: {std_err}")
# Out:
# Slope: 7755.60847641287
# Intercept: -2255.9240843183493
# R-squared: 0.8493647018102961
# P-value: 0.0
# Standard Error: 14.064131278395333

# %% [markdown]
# **What do you think?**

# %%
#your thoughts here

#Slope indicates strong price increase. Shows larger diamonds are more expensive

#R2 :around 84.93% of the variability in the diamond prices. 
#This is a high value, suggesting that carat weight is a strong predictor of price.

#P-value of 0.0 indicates that the relationship between carat and price is statistically significant

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#your thoughts here

#Given the results carat has a strong influence, but it's also important to consider other
#features. 

#For example, two diamonds of equal weight might have significantly different prices due
#to clarity, color and cut.

# %% [markdown]
# **Conclusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.

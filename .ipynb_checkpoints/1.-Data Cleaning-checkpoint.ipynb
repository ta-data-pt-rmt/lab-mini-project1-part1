# %% [markdown]
# # Descriptive Statistics Review

# %% [markdown]
# ## Before you start:
#
# - Read the README.md file
# - Comment as much as you can
# - Happy learning!

# %% [markdown]
# ## Context

# %% [markdown]
# ![img](./diamonds.jpg)

# %% [markdown]
# In this lab we are going to work with data to understand the characteristics of a diamond that are most likely to influence its price. In this first part of the lab, we will explore and clean our data.
#
# The dataset we will be using is comprised of approximately 54k rows and 11 different columns. As always, a row represents a single observation (in this case a diamond) and each of the columns represent a different feature of a diamond.
#
# The following codebook was provided together with the dataset to clarify what each column represents:

# %% [markdown]
# | Column  | Description  |
# |---|---|
# | Price  | Price in US dollars (326-18,823)  |
# | Carat  | Weight of the diamond (0.2--5.01)  |
# | Cut  | Quality of the cut (Fair, Good, Very Good, Premium, Ideal)  |
# | Color  | Diamond colour, from J (worst) to D (best)  |
# | Clarity  | A measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))   |
# | x  | Length in mm (0--10.74)  |
# | y  | Width in mm (0--58.9)  |
# | z  | Depth in mm (0--31.8)  |
# | Depth  | Total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)  |
# | Table  | Width of top of diamond relative to widest point (43--95)  |

# %% [markdown]
# ## Libraries
# Pandas and numpy will be needed for the analysis of the data.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# First import the data from the .csv file provided and assign it to a variable named `diamonds` and **drop the column with the index.**

# %%
#your code here
diamonds = pd.read_csv('diamonds.csv')

# %% [markdown]
# # 1. Taking the first look at the data.
# Let's see how the data looks by using pandas methods like `head()`, `info()` and `describe()`.
#
# **First, use the `head` method.**

# %%
#your code here
diamonds.head(3)
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31

# %%
#validating nulls
diamonds.isna().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
diamonds['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
diamonds['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
diamonds['color'].value_counts()
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
diamonds['color'].unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
diamonds['clarity'].value_counts()
# Out:
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: clarity, dtype: int64

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
diamonds.shape
# Out:
# (53940, 11)

# %%
diamonds.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %% [markdown]
# We can see the first 5 rows of the dataset using the `head` method. This by itself doesn't tell us much about the data that we have, but we can have a first look at the features (columns) and some of the values that each one takes.
#
# **What do you see? Make some comments about the values you see in each column, comparing them with the codebook. Is that what you would expect for these variables?**

# %%
#your code here
#We have 53940 lines with no null values
#We have a big range in carat(weight), is between the standards provided (0.2--5.01)
#cut< we identify the 5 values and which observation has more lines ideal , premium,vey good, good fair
#Color: we identify 7  as the codebook mention
#Clarity 8 values
#price wide range, and posible correlation with carat, possible guess>smaller cheapest 
# X (0--10.74) in the codebook 
# Y (0--58.9) in the codebook 
#Z (0--31.8) oin the codebook

# %% [markdown]
# It is very important to know the amount of data we have, because everything will depend on that, from the quality of the analysis to the choice of our infrastracture.
#
# **Check the shape of the data**

# %%
#your code here
diamonds.shape
# Out:
# (53940, 11)

# %% [markdown]
# The `clarity` column is confusing because we are not diamond experts. Let's modify this column with a new scale that is more understandable for us.
#
# **Modify `clarity` column with numbers from 0 to 7. The lowest would be 0 with value `I1` and the greatest 7 with value `IF`**

# %%
#your code here
diamonds['clarity'].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
def class_clarity(dataframe):
    conditions = [diamonds['clarity'].str.match('I1'),
                  diamonds['clarity'].str.match('SI2'),
                  diamonds['clarity'].str.match('SI1'),
                  diamonds['clarity'].str.match('VS2'),
                  diamonds['clarity'].str.match('VS1'),
                  diamonds['clarity'].str.match('VVS2'),
                  diamonds['clarity'].str.match('VVS1'),
                  diamonds['clarity'].str.match('IF')]

    choices =['0','1','2','3','4','5','6','7']

    diamonds['clarity_n'] = np.select(conditions,choices)

    return dataframe

# %%
diamonds = class_clarity(diamonds)

# %%
diamonds[['clarity','clarity_n']]
diamonds[['clarity','clarity_n']][diamonds['clarity'] == 'SI1']
# Out:
#       clarity clarity_n
# 1         SI1         2
# 7         SI1         2
# 10        SI1         2
# 12        SI1         2
# 17        SI1         2
# ...       ...       ...
# 53931     SI1         2
# 53934     SI1         2
# 53935     SI1         2
# 53936     SI1         2
# 53937     SI1         2
#
# [13065 rows x 2 columns]

# %%
#diamonds.drop(['clarity_n','clarity_n1'], axis =1,inplace=True)

# %%
diamonds.sample(5)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 7298         7299   1.11  Very Good     I     SI2   61.1   58.0   4202  6.63
# 33170       33171   0.37    Premium     G     VS1   58.4   59.0    817  4.76
# 19248       19249   1.01    Premium     F     VS1   61.2   59.0   7982  6.48
# 28953       28954   0.31  Very Good     H     SI1   62.9   56.0    435  4.27
# 18438       18439   1.08    Premium     F     VS2   62.1   59.0   7501  6.54
#
#           y     z clarity_n
# 7298   6.69  4.07         1
# 33170  4.69  2.76         4
# 19248  6.42  3.95         4
# 28953  4.31  2.70         2
# 18438  6.59  4.08         3

# %% [markdown]
# It makes sense to do the same with the `color` column.
#
# **Do the same with values from 0 to 6. Read the codebook to see the match**

# %%
#your code here
diamonds['color'].unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
def class_color(dataframe):
    conditions = [diamonds['color'].str.match('D'),
                  diamonds['color'].str.match('E'),
                  diamonds['color'].str.match('F'),
                  diamonds['color'].str.match('G'),
                  diamonds['color'].str.match('H'),
                  diamonds['color'].str.match('I'),
                  diamonds['color'].str.match('J'),]

    choices =['0','1','2','3','4','5','6']

    diamonds['color_n'] = np.select(conditions,choices)

    return dataframe

# %%
diamonds = class_color(diamonds)

# %%
diamonds
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z clarity_n color_n
# ...

# %% [markdown]
# With the `info` method, we can see the features of the dataset, and the amount of observations (rows) that have a non-null value and the types of the features.
#
# **Now use the `info` method and comparing with the shape, comment on what you see**

# %%
#your code here
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
#  11  clarity_n   53940 non-null  object
#  12  color_n     53940 non-null  object
# dtypes: float64(6), int64(2), object(5)
# memory usage: 5.4+ MB

# %% [markdown]
# In the last line of the info output, you have some information about the types of the columns. As you know, it is a good idea to check if the types of each column is what you expect. If a column has the right type, we will be able to do all the operations that we want to do.
#
# For instance, if we have a column that is a `date` with a `string` format, we will have the data but we won't be able to do a simple operation, such as format the date the way that we would like.
#
# Changing the data type to the one we needs can help us to solve a lot of problems in our data.
#
# **Check the types of each column and comment if it matches with the expected**

# %%
#your code here
#We use to_numeric to conver the last 2 columns created 
diamonds[['clarity_n','color_n']] = diamonds[['clarity_n','color_n']].apply(pd.to_numeric)

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
#  11  clarity_n   53940 non-null  int64
#  12  color_n     53940 non-null  int64
# dtypes: float64(6), int64(4), object(3)
# memory usage: 5.4+ MB

# %% [markdown]
# # 2. A deeper look: checking the basic statistics.
#
# The `describe` method gives us an overview of our data. From here we can see all the descriptive metrics for our variables.
#
# **Use the `describe` method and comment on what you see**

# %%
#your code and comments here
diamonds.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z     clarity_n       color_n
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734      3.051020      2.594197
# ...

# %% [markdown]
# You have probably noticed that the columns x, y and z have a minimum value of 0. This means that there are one or more rows (or observations) in our dataset that are supposedly representing a diamond that has lenght, width or depth of 0. Considering that we're talking about a physical object, this is impossible!
#
# Now let's proceed to check the rows that have a value of 0 in any of the x, y or z columns. By doing this we want to check if the data we are missing can be obtained using the data that we do have.
#
# **Check the columns with `x`, `y` and `z` with value 0 in all of them and comment what you see**

# %%
#your code here
print("x=0",diamonds['x'][diamonds['x']==0].count())
print("y=0",diamonds['y'][diamonds['y']==0].count())
print("z=0",diamonds['z'][diamonds['z']==0].count())
print("x,y,z=0",diamonds[['z','x','y']][(diamonds['z']==0) | (diamonds['x']==0) | (diamonds['y']==0)].count())
# Out:
# x=0 8
# y=0 7
# z=0 20
# x,y,z=0 z    20
# x    20
# y    20
# dtype: int64

# %%
diamonds[(diamonds['z']==0) & (diamonds['x']==0) & (diamonds['y']==0)]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price    x  \
# 11963       11964   1.00  Very Good     H     VS2   63.3   53.0   5139  0.0
# 15951       15952   1.14       Fair     G     VS1   57.5   67.0   6381  0.0
# 24520       24521   1.56      Ideal     G     VS2   62.2   54.0  12800  0.0
# 26243       26244   1.20    Premium     D    VVS1   62.1   59.0  15686  0.0
# 27429       27430   2.25    Premium     H     SI2   62.8   59.0  18034  0.0
# 49556       49557   0.71       Good     F     SI2   64.1   60.0   2130  0.0
# 49557       49558   0.71       Good     F     SI2   64.1   60.0   2130  0.0
#
#          y    z  clarity_n  color_n
# 11963  0.0  0.0          3        4
# 15951  0.0  0.0          4        3
# 24520  0.0  0.0          3        3
# 26243  0.0  0.0          6        0
# 27429  0.0  0.0          1        4
# 49556  0.0  0.0          1        2
# 49557  0.0  0.0          1        2

# %%
# We identify 
diamonds[(diamonds['y']!= 0) & (diamonds['x']!= 0) & (diamonds['z'] == 0)].count()
# Out:
# Unnamed: 0    12
# carat         12
# cut           12
# color         12
# clarity       12
# depth         12
# table         12
# price         12
# x             12
# y             12
# z             12
# clarity_n     12
# color_n       12
# dtype: int64

# %%
diamonds[(diamonds['y']!= 0) & (diamonds['x']!= 0) & (diamonds['z'] == 0)]
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price     x  \
# 2207         2208   1.00  Premium     G     SI2   59.1   59.0   3142  6.55
# 2314         2315   1.01  Premium     H      I1   58.1   59.0   3167  6.66
# 4791         4792   1.10  Premium     G     SI2   63.0   59.0   3696  6.50
# 5471         5472   1.01  Premium     F     SI2   59.2   58.0   3837  6.50
# 10167       10168   1.50     Good     G      I1   64.0   61.0   4731  7.15
# 13601       13602   1.15    Ideal     G     VS2   59.2   56.0   5564  6.88
# 24394       24395   2.18  Premium     H     SI2   59.4   61.0  12631  8.49
# 26123       26124   2.25  Premium     I     SI1   61.3   58.0  15397  8.52
# 27112       27113   2.20  Premium     H     SI1   61.2   59.0  17265  8.42
# 27503       27504   2.02  Premium     H     VS2   62.7   53.0  18207  8.02
# 27739       27740   2.80     Good     G     SI2   63.8   58.0  18788  8.90
# ...

# %% [markdown]
# As you can see, we have 20 rows that have a value of 0 in some or all the aforementioned columns.
# Most of them (12) are missing the z value, which we can obtain using the columns depth, x and y.
#
# 20 rows with issues represent just 0.03% of our data (20 out of 53940) so it wouldn't be a big deal to remove them. Still, lets try to keep all the data we have.
#
# For those 12 rows, we will create a function that applies the formula given in the codebook and get the value of z.
#
# **Create a function named `calculate_z` that applies the function in the codebook to one single row you give to the function**

# %%
#your code here
# Total depth percentage = z / mean(x, y) = 2 * z / (x + y)
# z / mean(x, y) = 2 * z / (x + y)
#  z =  depth (x+y) / 2

# %%
def calc_z(row):
    return (diamonds['depth'][row]/100)*((diamonds['x'][row]+diamonds['y'][row])/2)

# %%
def calc_z1(row):
    return (row['depth']/100)*((row['x']+row['y'])/2)

# %%
def calc_z2(row):
    if (row['y']!= 0) & (row['x']!= 0) & (row['z'] == 0):
        return (row['depth']/100)*((row['x']+row['y'])/2)

# %%
#diamonds['z_try'] = diamonds.apply(lambda row: row["x"]+row["y"]  if row['x'] != 0 else 'S' ) # & row['y'] != 0 & row['z'] == 0

# %%
diamonds.apply(calc_z2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\SERGIO~1\AppData\Local\Temp/ipykernel_15244/2410827191.py in <module>
# ----> 1 diamonds.apply(calc_z2)
#
# C:\dataanalyst\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# C:\dataanalyst\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# C:\dataanalyst\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ...

# %%
print(calc_z(0))
print(calc_z(2314))

#diamonds['z'].apply(calc_z1)

# %%
diamonds['z_calc']=diamonds.apply(calc_z1, axis=1)

# %%
diamonds
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
# ...

# %%
diamonds
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
# ...

# %%
#diamonds3 = diamonds.mask((diamonds['y']!= 0) & (diamonds['x']!= 0) & (diamonds['z'] == 0),1)#axis=1
diamonds['z'].where((diamonds['y']!= 0) & (diamonds['x']!= 0) & (diamonds['z'] == 0),diamonds['x']+diamonds['y'])
# Out:
# 0         7.93
# 1         7.73
# 2         8.12
# 3         8.43
# 4         8.69
#          ...
# 53935    11.51
# 53936    11.44
# 53937    11.34
# 53938    12.27
# 53939    11.70
# Name: z, Length: 53940, dtype: float64

# %%
#select

conditions = [(diamonds['y']!= 0) & (diamonds['x']!= 0) & (diamonds['z'] == 0)]

choises = [(diamonds['depth']/100)*((diamonds['x']+diamonds['y'])/2)]

diamonds['z'] = np.select(conditions,choises,diamonds['z'] )

# %%
diamonds
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
# ...

# %%
diamonds['z'][2207]
# Out:
# 3.850365

# %%
diamonds[(diamonds['y']!= 0) & (diamonds['x']!= 0) & (diamonds['z'] == 0)]['z'] = diamonds['x']+ diamonds['y']

# %%
diamonds['z'][2207]
# Out:
# 3.850365

# %%
diamonds3.sample(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SERGIO~1\AppData\Local\Temp/ipykernel_15244/3808759510.py in <module>
# ----> 1 diamonds3.sample(10)
#
# NameError: name 'diamonds3' is not defined

# %%
#diamonds2[(diamonds2['y']!= 0) & (diamonds2['x']!= 0) & (diamonds2['z'] == 0)]
diamonds3['z'][2207]
#diamonds3['z'][2314]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SERGIO~1\AppData\Local\Temp/ipykernel_15244/2558557846.py in <module>
#       1 #diamonds2[(diamonds2['y']!= 0) & (diamonds2['x']!= 0) & (diamonds2['z'] == 0)]
# ----> 2 diamonds3['z'][2207]
#       3 #diamonds3['z'][2314]
#       4
#
# NameError: name 'diamonds3' is not defined

# %%
diamonds2[(diamonds2['y']!= 0) & (diamonds2['x']!= 0) & (diamonds2['z'] == 0)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SERGIO~1\AppData\Local\Temp/ipykernel_15244/3107177590.py in <module>
# ----> 1 diamonds2[(diamonds2['y']!= 0) & (diamonds2['x']!= 0) & (diamonds2['z'] == 0)]
#
# NameError: name 'diamonds2' is not defined

# %%
#Not working, it doesnt overwrites
#diamonds[(diamonds['y']!= 0) & (diamonds['x']!= 0) & (diamonds['z'] == 0)]['z'] = diamonds[(diamonds['y']!= 0) & (diamonds['x']!= 0) & (diamonds['z'] == 0)].apply(calc_z1, axis=1)
#diamonds[(diamonds['y']!= 0) & (diamonds['x']!= 0) & (diamonds['z'] == 0)]

# %% [markdown]
# **Apply it just to the rows with incorrect values**

# %%
#your code here

# %% [markdown]
# If we leave the other 8 values as they are, it would negatively affect our analysis, because these are data that do not make logical sense. Therefore it is better to consider those values as NaN values, since they are probably the result of a mistake or error during process of measuring and storing these values in a dataset.
#
# To replace them we can use the pandas .replace() method and np.NaN.
#
# **Replace the zero values in the `z` column for a NaN**

# %%
#your code here
diamonds['x'][diamonds['x'] == 0].replace(0.0,np.NaN)
# Out:
# 11182   NaN
# 11963   NaN
# 15951   NaN
# 24520   NaN
# 26243   NaN
# 27429   NaN
# 49556   NaN
# 49557   NaN
# Name: x, dtype: float64

# %%
diamonds['x'][diamonds['x'] == 0] = diamonds['x'][diamonds['x'] == 0].replace(0.0,np.NaN)
# Out:
# C:\Users\SERGIO~1\AppData\Local\Temp/ipykernel_15244/3597921287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['x'][diamonds['x'] == 0] = diamonds['x'][diamonds['x'] == 0].replace(0.0,np.NaN)

# %%
diamonds[diamonds['x']==0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, carat, cut, color, clarity, depth, table, price, x, y, z, clarity_n, color_n, z_calc]
# Index: []

# %%
diamonds['y'][diamonds['y'] == 0]
# Out:
# 11963    0.0
# 15951    0.0
# 24520    0.0
# 26243    0.0
# 27429    0.0
# 49556    0.0
# 49557    0.0
# Name: y, dtype: float64

# %%
diamonds['y'][diamonds['y'] == 0]  = diamonds['y'][diamonds['y'] == 0].replace(0.0,np.NaN)
# Out:
# C:\Users\SERGIO~1\AppData\Local\Temp/ipykernel_15244/1918682209.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['y'][diamonds['y'] == 0]  = diamonds['y'][diamonds['y'] == 0].replace(0.0,np.NaN)

# %%
diamonds[diamonds['y']==0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, carat, cut, color, clarity, depth, table, price, x, y, z, clarity_n, color_n, z_calc]
# Index: []

# %%
diamonds['y'].isna().sum()
# Out:
# 7

# %%
diamonds['x'].isna().sum()
# Out:
# 8

# %% [markdown]
# Let's check the data again with the `describe()` method.

# %%
#your code here
diamonds.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z     clarity_n       color_n  \
# count  53932.000000  53933.000000  53940.000000  53940.000000  53940.000000
# mean       5.732007      5.735270      3.539740      3.051020      2.594197
# ...

# %% [markdown]
# The minimum value for x, y and z should now be a positive number, as it should be for the physical measurements of an object.

# %% [markdown]
# Let's finish by checking for NaN values in the data. Since we introduced them ourselves using 'replace', we will surely find some, but there may be more that are unrelated to the x, y and z columns. Checking NaNs is a fundamental part of data cleaning and it's always better to do this kind of operations before proceeding with analysis.
#
# **Check how many NaNs do you have, comment what you would do with those values, and then do so**

# %%
#your code here
diamonds.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             8
# y             7
# z             0
# clarity_n     0
# color_n       0
# z_calc        0
# dtype: int64

# %%
#there are few , is better to dropthem
diamonds.dropna(inplace=True)

# %%
diamonds.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# clarity_n     0
# color_n       0
# z_calc        0
# dtype: int64

# %% [markdown]
# # 3. Checking for outliers
# Now we are going to revisit the summary table to check for outliers.
#
# **Use the `describe` method again and comment on what you see. After that, check if you have any outliers**

# %%
#your code here
diamonds.describe()
# Out:
#         Unnamed: 0         carat         depth         table         price  \
# count  53932.00000  53932.000000  53932.000000  53932.000000  53932.000000
# mean   26970.48804      0.797879     61.749336     57.457029   3932.136079
# std    15571.46971      0.473986      1.432514      2.234064   3988.734835
# min        1.00000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.75000      0.400000     61.000000     56.000000    949.750000
# 50%    26971.50000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.25000      1.040000     62.500000     59.000000   5324.000000
# max    53940.00000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z     clarity_n       color_n  \
# count  53932.000000  53932.000000  53932.000000  53932.000000  53932.000000
# mean       5.732007      5.735254      3.540265      3.051101      2.594211
# ...

# %% [markdown]
# x	Length in mm (0--10.74)
# y	Width in mm (0--58.9)
# z	Depth in mm (0--31.8)

# %%
#your comments here

diamonds[diamonds['y'] >= 7]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 659           660   1.27    Premium     H     SI2   59.3   61.0   2845  7.12
# 1362         1363   1.50       Fair     H      I1   65.6   54.0   2964  7.26
# 2024         2025   1.52       Good     E      I1   57.3   58.0   3105  7.53
# 2025         2026   1.52       Good     E      I1   57.3   58.0   3105  7.53
# 2411         2412   1.50       Good     G      I1   57.4   62.0   3179  7.56
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 27746       27747   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20
# 27747       27748   1.51      Ideal     G      IF   61.7   55.0  18806  7.37
# 27748       27749   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90
# 27749       27750   2.29    Premium     I     VS2   60.8   60.0  18823  8.50
# 49189       49190   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15
#
# ...

# %% [markdown]
# To manage these outliers, we are going to filter our DataFrame, we're going to take all the values that have a price higher than the 75th percentile.
#
# **Look for that quantile and filter the dataframe to clearly see the outliers. What do you think?**

# %%
#your code here

diamonds_no75per = diamonds[(diamonds.price < diamonds.price.quantile(.75))]

# %%
diamonds_no75per.drop('z',axis=1,inplace =True)
# Out:
# C:\dataanalyst\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
diamonds_no75per.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  40446.000000  40446.000000  40446.000000  40446.000000  40446.000000
# mean   29212.958340      0.588530     61.757578     57.347367   2012.483756
# std    17233.103091      0.271136      1.426473      2.254785   1420.936257
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    10112.250000      0.340000     61.100000     56.000000    810.000000
# 50%    33715.500000      0.520000     61.800000     57.000000   1571.000000
# 75%    43826.750000      0.760000     62.500000     59.000000   3000.750000
# max    53940.000000      2.060000     79.000000     79.000000   5323.000000
#
#                   x             y     clarity_n       color_n        z_calc
# count  40446.000000  40446.000000  40446.000000  40446.000000  40446.000000
# mean       5.255605      5.260763      3.115463      2.438041      3.247211
# ...

# %% [markdown]
# Our dataset is really big and the outliers are really far apart from the rest of the values. To see this more clearly we will use a boxplot, which plots the median, 25th and 75th quartile, the maximum and minimum, as well as any outliers.

# %%
#Run this code
fig, ax = plt.subplots(1,2, figsize=(10, 5))
sns.boxplot(y=diamonds.y, ax=ax[0])
sns.boxplot(y=diamonds.z, ax=ax[1])
plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# Now we can see that all the values are within an acceptable range, but we have 2 big outliers in y and 1 in z. Now we know that our max values for y should be around 10 and the values for z should be around 6, so let's filter our dataset to find values for z higher than 10 in it.

# %%
#your code here
fig, ax = plt.subplots(1,2, figsize=(10, 5))
sns.boxplot(y=diamonds_no75per.y, ax=ax[0])
sns.boxplot(y=diamonds_no75per.z_calc, ax=ax[1])
plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# Now that we have found the outlier, let's use the function we defined earlier to correct this value. First, we need to change the value to 0 (because that's how we defined the function before) and then we will apply it.
#
# **Apply `calculate_z` for the row with the outlier**

# %%
#your code here
def calc_z1(diamonds_no75per):
    return (row['depth']/100)*((row['x']+row['y'])/2)

# %%
calc_z1(48411)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\SERGIO~1\AppData\Local\Temp/ipykernel_15244/3892225834.py in <module>
# ----> 1 calc_z1(48411)
#
# C:\Users\SERGIO~1\AppData\Local\Temp/ipykernel_15244/3899368466.py in calc_z1(row)
#       1 #your code here
#       2 def calc_z1(row):
# ----> 3     return (row['depth']/100)*((row['x']+row['y'])/2)
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# Let's check if we actually corrected the outlier.

# %%
diamonds.loc[48410]
# Out:
# Unnamed: 0        48411
# carat              0.51
# cut           Very Good
# color                 E
# clarity             VS1
# depth              61.8
# table              54.7
# price              1970
# x                  5.12
# y                  5.15
# z                  31.8
# clarity_n             4
# color_n               1
# z_calc          3.17343
# Name: 48410, dtype: object

# %% [markdown]
# Now let's do the same for `y`. First, let's filter the DataFrame to find the outliers. We said that the maximum values should be around 10, so let's check what are the values above 10.
#
# **Check the values greater than 10 in the `y` column**

# %%
#your code here
diamonds_no75per[diamonds_no75per['y']>10]
# Out:
#        Unnamed: 0  carat    cut color clarity  depth  table  price     x  \
# 49189       49190   0.51  Ideal     E     VS1   61.8   55.0   2075  5.15
#
#           y  clarity_n  color_n    z_calc
# 49189  31.8          4        1  11.41755

# %%
diamonds_no75per[diamonds_no75per['z_calc']>6]
# Out:
#        Unnamed: 0  carat    cut color clarity  depth  table  price     x  \
# 49189       49190   0.51  Ideal     E     VS1   61.8   55.0   2075  5.15
#
#           y  clarity_n  color_n    z_calc
# 49189  31.8          4        1  11.41755

# %%
[diamonds_no75per.iloc[24067]]
# Out:
# [Unnamed: 0      37560
#  carat            0.31
#  cut           Premium
#  color               G
#  clarity            IF
#  depth            61.4
#  table            59.0
#  price             988
#  x                4.39
#  y                4.34
#  clarity_n           7
#  color_n             3
#  z_calc        2.68011
#  Name: 37559, dtype: object]

# %% [markdown]
# We can clearly see that the 31.8 in row 49189 is an outlier for the y value. Also, we can see that the 58.9 value for `y` in row 24067 is actually its depth, so it was a mistake when they introduced the data. Let's create a function to fix these outliers.
#
# **Create a function named `calculate_y` to calculate `y` using `z` and `x` the same way you did above**

# %%
#your code here

# %% [markdown]
# We will check the rows that had an outlier in `y`, to check that the values were changed.
#
# **Check those rows and comment what you see**

# %%
#your thoughts here

# %% [markdown]
# Now that we have corrected or dropped all of our outliers, lets plot another box plot to double check.

# %%
#Run this code
fig, ax = plt.subplots(1,2, figsize=(10, 5))
sns.boxplot(y=diamonds_no75per.y, ax=ax[0])
sns.boxplot(y=diamonds_no75per.z_calc, ax=ax[1])
plt.subplots_adjust(wspace=0.5)

# %%
diamonds_no75per = diamonds_no75per.drop(labels=[49189], axis=0)

# %%
fig, ax = plt.subplots(1,2, figsize=(10, 5))
sns.boxplot(y=diamonds_no75per.y, ax=ax[0])
sns.boxplot(y=diamonds_no75per.z_calc, ax=ax[1])
plt.subplots_adjust(wspace=0.5)

# %%
diamonds_no75per
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y  clarity_n  color_n    z_calc
# ...

# %%
diamonds_no75per = diamonds_no75per.rename(columns={"z_calc": "z"})

# %%
diamonds_no75per.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#    clarity_n  color_n         z
# 0          1        1  2.438475
# 1          2        1  2.311270
# 2          4        1  2.310140
# 3          3        5  2.630160
# 4          1        6  2.750385

# %% [markdown]
# **What do you think? Are these values more reasonable?**

# %%
#your thoughts here
#Yes the value for those outliyers were to high, now they are in a more razonable range

# %% [markdown]
# **Once you are happy with your cleaning, save the cleaned data and continue to csv. Your new csv should be named ``diamonds_clean.csv``**

# %%
#your code here
diamonds_no75per.to_csv('diamonds_clean.csv')
